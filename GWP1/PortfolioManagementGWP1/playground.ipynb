# %%
import polars as pl
ff3 = pl.read_csv("FF3.csv").with_columns(pl.col("").cast(pl.String).str.to_date("%Y%m%d")).rename({"": "Date"})

# %%
ff3.select(pl.exclude("Date")).corr()
# Out:
# shape: (4, 4)
# ┌───────────┬───────────┬───────────┬───────────┐
# │ Mkt-RF    ┆ SMB       ┆ HML       ┆ RF        │
# │ ---       ┆ ---       ┆ ---       ┆ ---       │
# │ f64       ┆ f64       ┆ f64       ┆ f64       │
# ╞═══════════╪═══════════╪═══════════╪═══════════╡
# │ 1.0       ┆ -0.144884 ┆ 0.150888  ┆ -0.014266 │
# │ -0.144884 ┆ 1.0       ┆ -0.071755 ┆ -0.011049 │
# │ 0.150888  ┆ -0.071755 ┆ 1.0       ┆ 0.008671  │
# │ -0.014266 ┆ -0.011049 ┆ 0.008671  ┆ 1.0       │
# └───────────┴───────────┴───────────┴───────────┘

# %%
from visualisation import plot_multiline_chart
plot_multiline_chart([(ff3['Date'], ff3['SMB'], "Small Minus Big")], title="Small Minus Big", x_label="Date", y_label="Small Minus Big")
plot_multiline_chart([(ff3['Date'], ff3['HML'], "High Minus Low")], title="High Minus Low", x_label="Date", y_label="High Minus Low")

# %%
import importlib
import visualisation
importlib.reload(visualisation)
from visualisation import plot_multiscatter

# %%
plot_multiscatter([(ff3['SMB'], ff3['Mkt-RF'], "High Minus Low")], title="High Minus Low", x_label="Date", y_label="High Minus Low")
# Out:
# <module 'matplotlib.pyplot' from 'c:\\Users\\kumar\\AppData\\Local\\Programs\\Python\\Python312\\Lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
plot_multiscatter([(ff3['HML'], ff3['Mkt-RF'], "High Minus Low")], title="High Minus Low", x_label="Date", y_label="High Minus Low")
# Out:
# <module 'matplotlib.pyplot' from 'c:\\Users\\kumar\\AppData\\Local\\Programs\\Python\\Python312\\Lib\\site-packages\\matplotlib\\pyplot.py'>
